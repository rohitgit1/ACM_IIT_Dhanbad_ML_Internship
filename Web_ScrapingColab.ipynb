# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webPage = requests.get("https://www.ambitionbox.com/list-of-companies?page=1", headers = headers).text

# %%
soup = BeautifulSoup(webPage, 'lxml')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html data-n-head="%7B%22lang%22:%7B%22ssr%22:%22en%22%7D%7D" data-n-head-ssr="" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width,initial-scale=1" name="viewport"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <script type="text/javascript">\n   window.NREUM||(NREUM={}),NREUM.init={distributed_tracing:{enabled:!0}},window.NREUM||(NREUM={}),__nr_require=function(n,r,t){function o(e){if(!r[e]){var t=r[e]={exports:{}};n[e][0].call(t.exports,function(t){return o(n[e][1][t]||t)},t,t.exports)}return r[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var e=0;e<t.length;e++)o(t[e]);return o}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(t){}}var o,i=t("ee"),a=t(25),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,-1!==o.indexOf("dev")&&(s.dev=!0),-1!==o.indexOf("nr_dev")&&(s.nrDev=!0))}catch(t){}s.nrDev&&i.on("interna
# ...

# %%
soup.find_all('h2')
# Out:
# [<h2 class="company-name bold-title-l" title="TCS">
#                  TCS
#                </h2>, <h2 class="company-name bold-title-l" title="Accenture">
#                  Accenture
#                </h2>, <h2 class="company-name bold-title-l" title="ICICI Bank">
#                  ICICI Bank
#                </h2>, <h2 class="company-name bold-title-l" title="Cognizant">
#                  Cognizant
#                </h2>, <h2 class="company-name bold-title-l" title="HDFC Bank">
#                  HDFC Bank
#                </h2>, <h2 class="company-name bold-title-l" title="Infosys">
#                  Infosys
#                </h2>, <h2 class="company-name bold-title-l" title="L&amp;T">
#                  L&amp;T
#                </h2>, <h2 class="company-name bold-title-l" title="Capgemini">
#                  Capgemini
#                </h2>, <h2 class="company-name bold-title-l" title="Tech Mahindra">
#                  Tech Mahindra
# ...

# %%
for i in soup.find_all('h2'):
  print(i.text.strip())
# Out:
# TCS
# Accenture
# ICICI Bank
# Cognizant
# HDFC Bank
# Infosys
# L&T
# Capgemini
# Tech Mahindra
# HCL Technologies
# IBM
# Tata Motors
# Reliance jio
# Genpact
# Axis Bank
# Concentrix Corporation
# Wipro
# Vodafone
# HDB Financial Services
# Bharti Airtel
# Kotak Mahindra Bank
# Amazon
# Reliance
# Bajaj Finserv
# IndusInd Bank
# Hinduja Global Solutions
# Samsung
# Indian Army
# Teleperformance
# Mahindra & Mahindra

# %%
len(soup.find_all('p', class_ = 'rating'))
# Out:
# 30

# %%
len(soup.find_all('a', class_ = 'review-count'))
# Out:
# 30

# %%
len(soup.find_all('p', class_ = 'infoEntity'))
# Out:
# 120

# %%
len(soup.find_all('div', class_ = 'company-content-wrapper'))
# Out:
# 30

# %%
company = soup.find_all('div', class_ = "company-content-wrapper")

# %%
len(company)
# Out:
# 30

# %%
# name = []
# for i in company:
#   name.append(i.find('h2').text.strip())

# %%
name = []
rating = []
reviews = []
companyType = []
headQuarters = []
old = []
employees = []

for i in company:
  name.append(i.find('h2').text.strip())
  rating.append(i.find('p', class_ = 'rating').text.strip())
  reviews.append(i.find('a', class_ = 'review-count').text.strip())
  companyType.append(i.find_all('p', class_ = "infoEntity")[0].text.strip())
  headQuarters.append(i.find_all('p', class_ = "infoEntity")[1].text.strip())
  old.append(i.find_all('p', class_ = "infoEntity")[2].text.strip())
  try:
    employees.append(i.find_all('p', class_ = "infoEntity")[3].text.strip())
  except:
    employees.append(np.nan)
    
d = {'name': name, 'rating': rating, 'Type': companyType, 'HQ': headQuarters, 'old': old, 'employees': employees}
df = pd.DataFrame(d)
df
# Out:
#                         name rating  ...            old         employees
# 0                        TCS    3.9  ...   52 years old  10000+ employees
# 1                  Accenture    4.0  ...   31 years old  10000+ employees
# 2                 ICICI Bank    4.1  ...   26 years old  10000+ employees
# 3                  Cognizant    3.9  ...   26 years old  10000+ employees
# 4                  HDFC Bank    4.0  ...   26 years old  10000+ employees
# 5                    Infosys    3.9  ...   39 years old  10000+ employees
# 6                        L&T    4.1  ...   82 years old  10000+ employees
# 7                  Capgemini    3.3  ...   53 years old  10000+ employees
# 8              Tech Mahindra    3.6  ...   34 years old  10000+ employees
# 9           HCL Technologies    3.7  ...   14 years old  10000+ employees
# 10                       IBM    4.0  ...  109 years old  10000+ employees
# 11               Tata Motors    4.1  ...   75 years old  10000+ employees
# ...

# %%
df.shape
# Out:
# (30, 6)

# %%
name
# Out:
# ['TCS',
#  'Accenture',
#  'ICICI Bank',
#  'Cognizant',
#  'HDFC Bank',
#  'Infosys',
#  'L&T',
#  'Capgemini',
#  'Tech Mahindra',
#  'HCL Technologies',
#  'IBM',
#  'Tata Motors',
#  'Reliance jio',
#  'Genpact',
#  'Axis Bank',
#  'Concentrix Corporation',
#  'Wipro',
#  'Vodafone',
#  'HDB Financial Services',
#  'Bharti Airtel',
#  'Kotak Mahindra Bank',
#  'Amazon',
#  'Reliance',
#  'Bajaj Finserv',
#  'IndusInd Bank',
#  'Hinduja Global Solutions',
#  'Samsung',
#  'Indian Army',
#  'Teleperformance',
#  'Mahindra & Mahindra']

# %%
rating
# Out:
# ['3.9',
#  '4.0',
#  '4.1',
#  '3.9',
#  '4.0',
#  '3.9',
#  '4.1',
#  '3.3',
#  '3.6',
#  '3.7',
#  '4.0',
#  '4.1',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '3.8',
#  '4.3',
#  '4.0',
#  '4.2',
#  '3.8',
#  '4.2',
#  '4.2',
#  '4.1',
#  '3.6',
#  '3.8',
#  '4.2',
#  '4.7',
#  '3.7',
#  '4.2']

# %%
reviews
# Out:
# ['16.3k Reviews',
#  '14.3k Reviews',
#  '12.9k Reviews',
#  '12.3k Reviews',
#  '11.2k Reviews',
#  '10.8k Reviews',
#  '10k Reviews',
#  '9.6k Reviews',
#  '9.2k Reviews',
#  '8.8k Reviews',
#  '8.2k Reviews',
#  '8.2k Reviews',
#  '7.9k Reviews',
#  '7.9k Reviews',
#  '7.7k Reviews',
#  '6.9k Reviews',
#  '6.7k Reviews',
#  '6k Reviews',
#  '5.7k Reviews',
#  '5.5k Reviews',
#  '5.3k Reviews',
#  '5.1k Reviews',
#  '4.7k Reviews',
#  '3.9k Reviews',
#  '3.7k Reviews',
#  '3.5k Reviews',
#  '3.5k Reviews',
#  '3.4k Reviews',
#  '3.2k Reviews',
#  '3.1k Reviews']

# %%
company[0].find_all('p', class_ = "infoEntity")[0].text.strip()
# Out:
# 'Public'

# %%
final = pd.DataFrame()
for j in range(1, 111):
  url = "https://www.ambitionbox.com/list-of-companies?page={}".format(j)
  headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
  webPage = requests.get(url, headers = headers).text
  soup = BeautifulSoup(webPage, 'lxml')
  company = soup.find_all('div', class_ = "company-content-wrapper")

  name = []
  rating = []
  reviews = []
  companyType = []
  headQuarters = []
  old = []
  employees = []

  for i in company:
    name.append(i.find('h2').text.strip())
    rating.append(i.find('p', class_ = 'rating').text.strip())
    reviews.append(i.find('a', class_ = 'review-count').text.strip())
    companyType.append(i.find_all('p', class_ = "infoEntity")[0].text.strip())
    try:
      headQuarters.append(i.find_all('p', class_ = "infoEntity")[1].text.strip())
    except:
      headQuarters.append(np.nan)
    try:
      old.append(i.find_all('p', class_ = "infoEntity")[2].text.strip())
    except:
      old.append(np.nan)
    try:
      employees.append(i.find_all('p', class_ = "infoEntity")[3].text.strip())
    except:
      employees.append(np.nan)

  d = {'name': name, 'rating': rating, 'Type': companyType, 'HQ': headQuarters, 'old': old, 'employees': employees}
  df = pd.DataFrame(d)
  final = final.append(df, ignore_index = True)

# %%
final.shape
# Out:
# (3300, 6)

# %%
final
# Out:
#                              name rating  ...            old           employees
# 0                             TCS    3.9  ...   52 years old    10000+ employees
# 1                       Accenture    4.0  ...   31 years old    10000+ employees
# 2                      ICICI Bank    4.1  ...   26 years old    10000+ employees
# 3                       Cognizant    3.9  ...   26 years old    10000+ employees
# 4                       HDFC Bank    4.0  ...   26 years old    10000+ employees
# ...                           ...    ...  ...            ...                 ...
# 3295             Corporation Bank    4.2  ...  114 years old    10000+ employees
# 3296                     CG Foods    4.2  ...   36 years old  501-1000 employees
# 3297                 Vacmet India    4.1  ...   27 years old  501-1000 employees
# 3298  The Indian Hotels Compan...    4.2  ...  121 years old    10000+ employees
# 3299                   Innovision    3.6  ...   13 years old    10000+ employees
#
# ...
